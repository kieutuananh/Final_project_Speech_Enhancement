# %%
from IPython.display import Audio
sr=16000

# %% [markdown]
# # *NOISES* & **PROCESS**

# %%
# Tieng cho sua
Audio('/content/drive/My Drive/sample/audio (3).wav',rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Tieng cho sua
Audio('./drive/My Drive/sample/enhancement_audio (3).wav',rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Tieng nguoi noi
Audio('/content/drive/My Drive/sample/audio (2).wav', rate = sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Tieng nguoi noi
Audio('./drive/My Drive/sample/enhancement_audio (2).wav',rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Tieng go ban
Audio('/content/drive/My Drive/sample/audio (1).wav', rate = sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Tieng go ban
Audio('/content/drive/My Drive/sample/enhancement_audio (1).wav', rate = sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
